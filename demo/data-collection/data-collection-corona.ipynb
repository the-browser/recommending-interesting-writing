# %%
#import necessary libraries
import numpy as np
from scipy.sparse import csr_matrix
from pathlib import Path
import sys
import pandas as pd
import torch
import collections
import numpy as np
import torch.nn as nn
import os
import argparse
sys.path.append("../../default-approach")
from data_processing.articles import Articles
from models.models import InnerProduct
import data_processing.dictionaries as dictionary
from pathlib import Path
import json
from pandas import json_normalize
import scipy
import boto3

dict_dir = Path("../../../data/dictionaries")
final_word_ids,final_url_ids, final_publication_ids = dictionary.load_dictionaries(dict_dir)
print("Dictionaries loaded.")

data_path = Path('../../../data/corona-feeds/scrape_data/corona-rss-articles-info.json')
dataset = Articles(data_path)
print("Data loaded.")

abs_model_path = Path("../../../data/gridsearch_results/2020-05-25/optimizer_type=RMS_use_all_words=False_emb_size=100_learning_rate=0.0001_word_embedding_type=mean/model/mean-inner-product-model.pt")
kwargs = dict(n_publications=len(final_publication_ids),
              n_articles=len(final_url_ids),
              n_attributes=len(final_word_ids),
              emb_size=100,
              sparse=False,
              use_article_emb=False,
              mode='mean')
model = InnerProduct(**kwargs)
model.load_state_dict(torch.load(abs_model_path))
print("Model Loaded.")

dataset.tokenize()
proper_data = dataset.map_items(final_word_ids,
                    final_url_ids,
                    final_publication_ids,
                    filter=True,
                    min_length=200)

data_path = Path("/users/rohan/news-classification/Data/corona-feeds")
if not data_path.is_dir():
    data_path.mkdir()
mapped_data_path = data_path / "mapped-data"
if not mapped_data_path.is_dir():
    mapped_data_path.mkdir()
train_mapped_path = mapped_data_path / "mapped_dataset.json"
with open(train_mapped_path, "w") as file:
    json.dump(proper_data, file)
raw_data = Articles(train_mapped_path)
print("Final: ", len(raw_data))
print(f"Filtered, Mapped Data saved to {mapped_data_path} directory")
print("-------------------")

word_articles = scipy.sparse.csr_matrix((len(raw_data), len(final_word_ids)), dtype=np.float32).toarray()

for idx, item in enumerate(raw_data.examples):
    item['text'] = list(set(item['text']))
    for entry in item['text']:
        word_articles[idx][entry] = 1

publication_emb = model.publication_embeddings.weight.data[0].cpu().numpy()
publication_bias = model.publication_bias.weight.data[0].cpu().numpy()
word_emb = model.attribute_emb_sum.weight.data.cpu().numpy()
word_bias = model.attribute_bias_sum.weight.data.cpu().numpy()
scipy.sparse.save_npz("/users/rohan/news-classification/Data/demo-data/sets/csr_articles_corona.npz", csr_matrix(word_articles))
print("Article-Word Matrix Saved")

'''
np.save("word_emb.npy", word_emb)
print("Word Embeddings Saved")

np.save("word_bias.npy", word_bias)
print("Word Biases Saved")

with open("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json",'r') as file:
    real_data = json.load(file)
    
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "r") as file:
    id_to_word = json.load(file)
'''
# Out:
# Dictionaries loaded.
# Data loaded.
# Model Loaded.
# Final:  1597
# Filtered, Mapped Data saved to \users\rohan\news-classification\Data\corona-feeds\mapped-data directory
# -------------------
# Article-Word Matrix Saved
# '\nnp.save("word_emb.npy", word_emb)\nprint("Word Embeddings Saved")\n\nnp.save("word_bias.npy", word_bias)\nprint("Word Biases Saved")\n\nwith open("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json",\'r\') as file:\n    real_data = json.load(file)\n    \nwith open(\'/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json\', "r") as file:\n    id_to_word = json.load(file)\n'

# %%
import numpy as np
from scipy.sparse import csr_matrix
import time
import json
import scipy

publication_emb = np.asarray([1.0440499, 1.0030843, 1.0340449, 0.992087, 1.0509816, 1.0315005, -1.0493797, -1.0198538, 0.9712321, -1.026394, 
            -0.9687971, 1.0592866, -1.0200703, -1.0423145, 0.9929519, 1.0220934, 1.021279, -1.0265925, 0.9601833, 0.9763889, 
            1.0109168, -0.9728226, 0.97199583, -1.0237931, -0.9996001, 0.9932069, 0.97966635, -0.98893607, -0.9876815, -0.98812914, 
            -0.9625895, 0.99879754, 0.9876508, -0.9581506, -0.95436096, -0.9601925, -1.0134513, -0.98763955, 0.98665, -1.0140482, 
            1.004904, 0.9894275, -1.0044671, -0.9839679, -0.97082543, -0.9798079, 0.9926766, -0.97317344, 0.9797, -0.97642475, 
            -0.99420726, -0.9972062, -1.0104703, 1.0575777, 0.9957696, -1.0413874, -1.0056863, -1.0151271, -0.99969465, 0.97463423, 
            -0.98398715, -1.0211866, -1.0128828, -1.0024365, -0.9800189, 1.0457181, 1.0155835, -1.036794, -1.013707, -1.0498024, 
            -1.0252678, -1.0388161, -0.97501564, 0.97687274, 0.97906756, 1.0536852, 1.0590494, -0.96917725, 1.0247189, -0.9818878, 
            -1.0417286, -1.0204054, -1.0285249, -1.0329671, 0.9705739, 0.96375024, 0.9891868, 0.9892464, 1.039075, 1.0042666,
            0.9786834, 1.0199072, 0.98080486, 0.9698635, -0.99322844, -0.95841753, -0.99150276, 0.97394156, 0.9976019, -1.0375009], dtype=np.float32)

publication_bias = 0.99557
word_articles = scipy.sparse.load_npz('/users/rohan/news-classification/Data/demo-data/sets/csr_articles_corona.npz')
word_emb = np.load('/users/rohan/news-classification/Data/demo-data/word_emb.npy')
word_bias = np.load('/users/rohan/news-classification/Data/demo-data/word_bias.npy')

with open("/users/rohan/news-classification/Data/corona-feeds/mapped-data/mapped_dataset.json",'r') as file:
    real_data = json.load(file)
    
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "r") as file:
    id_to_word = json.load(file)
print("Data Loaded Successfully!")

time1 = time.time()
article_embeddings = word_articles.dot(word_emb)

emb_times_publication = np.dot(article_embeddings, publication_emb.reshape(100,1))

article_bias = word_articles.dot(word_bias)

product_with_bias = emb_times_publication + article_bias

word_counts = word_articles.sum(axis=1).reshape(word_articles.shape[0], 1)

final_logits = np.divide(product_with_bias, word_counts) + float(publication_bias)

indices = final_logits.argsort(axis=0)[-75:].reshape(75)

word_logits = np.dot(word_emb, publication_emb.reshape(100,1)) + word_bias

top_articles = word_articles[indices.tolist()[0]]

broadcasted_words_per_article = top_articles.toarray() * word_logits.T

sorted_word_indices = broadcasted_words_per_article.argsort(axis=1)

return_articles = []

i=0
for idx in indices.tolist()[0]:
    current_article = raw_data[int(idx)]
    current_article['logit'] = float(final_logits[int(idx)])
    current_sorted_words = sorted_word_indices[i]
    top_words = []
    least_words = []
    for top_word in current_sorted_words[-10:]:
        word = id_to_word[str(top_word)]
        top_words.append(word)
    for least_word in current_sorted_words[:10]:
        word = id_to_word[str(least_word)]
        least_words.append(word)
    current_article['top_words'] = top_words
    current_article['least_words'] = least_words
    return_articles.append(current_article)
    i+=1
    
time2 = time.time()

print(time2-time1)
# Out:
# Data Loaded Successfully!
# 0.7484641075134277

# %%
def RepresentsInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

ordered_return_articles = return_articles[::-1]
grand_html = []
for idx, article in enumerate(ordered_return_articles):
    if not article['publication'] or len(article['publication']) > 35:
        continue
    grand_html.append("<tr>")
    grand_html.append(f"<td class=\"title mdl-data-table__cell--non-numeric\"><a class=\"article_link\" href=\"{article['link']}\">{article['title']}</a>")
    grand_html.append("<br></br>")
    grand_html.append("<br></br>")
    top_word_list = ""
    for item in article['top_words']:
        if len(item) > 2 and not RepresentsInt(item):
            top_word_list += item
            top_word_list += ", "
    least_word_list = ""
    for item in article['least_words']:
        if len(item) > 2:
            least_word_list += item
            least_word_list += ", "
    grand_html.append(f"<p class=\"top_words\">{top_word_list[:-2]}</p>")
    grand_html.append(f"<p class=\"least_words\">{least_word_list[:-2]}</p>")
    grand_html.append("</td>")
    grand_html.append(f"<td class=\"publication\">{article['publication']}</td>")
    grand_html.append(f"<td class=\"logit\">{article['logit']}</td>")
    grand_html.append("</tr>")
print("\n".join(grand_html))
# Out:
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/865685784/a-flight-attendant-shares-her-thoughts-about-returning-to-work?utm_medium=RSS&utm_campaign=allthingsconsidered">A Flight Attendant Shares Her Thoughts About Returning To Work</a>
# <br></br>
# <br></br>
# <p class="top_words">information, the, contractor, sitting, org, inc, pages, copyright</p>
# <p class="least_words">monday, 2020, ahead, letting, shares, actually, bit, here, dire</p>
# </td>
# <td class="publication">All Things Considered : NPR</td>
# <td class="logit">4.743221282958984</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newcriterion.com/blogs/dispatch/week-in-review-11574">Week in review</a>
# <br></br>
# <br></br>
# <p class="top_words">books, barry, crisis, manner, protocol, hobbes, nervous, seventy</p>
# <p class="least_words">rolling, quarantine, reminder, distancing, episode, above, writes, podcasts</p>
# </td>
# <td class="publication">The New Criterion Latest Blog</td>
# <td class="logit">3.9528772830963135</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/FgQKFYPXAcM/">What Kind of Country Do We Want?</a>
# <br></br>
# <br></br>
# <p class="top_words">anomalous, fiscal, expectation, occasional, image, ten, eighteenth, mitt, nineteenth, romney</p>
# <p class="least_words">read, related, hide, previously, statement, viral, according, earnings, drama</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">3.8671247959136963</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/no-close-encounters-of-any-kind/">No Close Encounters of Any Kind</a>
# <br></br>
# <br></br>
# <p class="top_words">twelve, ten, fifteen, thirteen, forty, thirty, twenty, advertisement</p>
# <p class="least_words">trump, read, quarantine, confederate, distancing, pretty, 2020, while, stars</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.7215702533721924</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/quarantine-pastoral/">Quarantine Pastoral</a>
# <br></br>
# <br></br>
# <p class="top_words">neighborhood, fourteen, occasional, bush, jeans, obama, fifteen, twenty</p>
# <p class="least_words">quarantine, stone, reminder, distancing, 2020, alongside, isn, according, visitors</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.650942087173462</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/billionaires-of-time/">Billionaires of Time</a>
# <br></br>
# <br></br>
# <p class="top_words">gray, tolstoy, hair, afternoon, jeans, fifteen, thirty, sixteen</p>
# <p class="least_words">read, related, quarantine, pretty, added, shows, isn, museum, while</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.6192212104797363</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/865685805/coronavirus-victims-a-former-high-school-football-player-teddy-nelson?utm_medium=RSS&utm_campaign=allthingsconsidered">Coronavirus Victims: A Former High School Football Player Teddy Nelson</a>
# <br></br>
# <br></br>
# <p class="top_words">the, everybody, knew, friend, contractor, remembers, org, inc, pages, copyright</p>
# <p class="least_words">2015, 2020, virginia, facebook, safeguard, told, lead</p>
# </td>
# <td class="publication">All Things Considered : NPR</td>
# <td class="logit">3.615570306777954</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newrepublic.com/article/157786/sounding-teaching-daughter-read-quarantine">Sounding It Out</a>
# <br></br>
# <br></br>
# <p class="top_words">minutes, the, knew, seemed, arithmetic, money, breakfast, crisis, onto, pages</p>
# <p class="least_words">read, quarantine, upload, video, while, trapped, families, sprint, landing</p>
# </td>
# <td class="publication">The New Republic</td>
# <td class="logit">3.6139395236968994</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://bitcoinmagazine.com/articles/what-is-happening-to-money?utm_source=rss&utm_medium=rss&utm_campaign=what-is-happening-to-money">What Is Happening to Money?</a>
# <br></br>
# <br></br>
# <p class="top_words">incentives, balance, inc, drive, whereas, credit, von, stimulus</p>
# <p class="least_words">digital, previously, code, according, doesn, due, popular, diversity, globally</p>
# </td>
# <td class="publication">Bitcoin Magazine</td>
# <td class="logit">3.5961952209472656</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/precise-and-prescient/">Precise and Prescient</a>
# <br></br>
# <br></br>
# <p class="top_words">avenue, occupy, pages, credit, translated, hundred, twenty</p>
# <p class="least_words">photograph, trump, read, thursday, donald, 2016, stone, uber, confirmed</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.3921687602996826</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/the-toothache/">The Toothache</a>
# <br></br>
# <br></br>
# <p class="top_words">gray, mentioned, clients, tea, drive, occasional, afternoon, fifteen, twenty</p>
# <p class="least_words">thursday, monday, clarity, quarantine, friday, recap, wrote, video, whatsapp</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.3692009449005127</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/last-laugh/">Last Laugh</a>
# <br></br>
# <br></br>
# <p class="top_words">upper, attractive, mentioned, occasional, avenue, thirteen, forty, thirty, twenty</p>
# <p class="least_words">explaining, read, twitter, rolling, changing, reminder, pretty, added, wrote</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.3007161617279053</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://thewalrus.ca/murder-in-old-barns/">Murder in Old Barns</a>
# <br></br>
# <br></br>
# <p class="top_words">fifteen, interviews, fifty, thirty, sixty, sixteen, seventy, twenty</p>
# <p class="least_words">photograph, explaining, 2017, season, friday, confirmed, pretty, added, shows</p>
# </td>
# <td class="publication">The Walrus</td>
# <td class="logit">3.109334945678711</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/whores-at-the-end-of-the-world/">Whores at the End of the World</a>
# <br></br>
# <br></br>
# <p class="top_words">pages, stimulus, ten, fifteen, hundred, fifty, twenty</p>
# <p class="least_words">read, twitter, tuesday, hide, quarantine, ezra, friday, recap, distancing, added</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.031867504119873</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/where-is-patricia-sigl/">Where Is Patricia Sigl?</a>
# <br></br>
# <br></br>
# <p class="top_words">talk, mentioned, neighborhood, tea, fourteen, eighties, sixties, fifty, eighteenth</p>
# <p class="least_words">brexit, thursday, quarantine, confirmed, distancing, pretty, added, boris, horror</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">3.0038695335388184</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newcriterion.com/blogs/dispatch/a-gala-cont">A gala, cont.</a>
# <br></br>
# <br></br>
# <p class="top_words">english, harp, excerpts, himself, ever, the, indeed, forty</p>
# <p class="least_words">beloved, statement, livestreaming, monologue, wagner, performances, also, spain, held</p>
# </td>
# <td class="publication">The New Criterion Latest Blog</td>
# <td class="logit">2.981576681137085</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://aeon.co/essays/what-is-the-problem-with-ethical-trolley-problems?utm_medium=feed&utm_source=rss-feed">The trolley problem problem</a>
# <br></br>
# <br></br>
# <p class="top_words">reader, obvious, analogy, onto, talk, assumed, domain, moreover, image, cent</p>
# <p class="least_words">read, clarity, 2015, researchers, wrote, defence, while, watch, doesn</p>
# </td>
# <td class="publication">Aeon</td>
# <td class="logit">2.9584531784057617</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/aRtqeTPuEl4/">A Virus in the Neighborhood</a>
# <br></br>
# <br></br>
# <p class="top_words">download, pages, blond, neighboring, ten, fifteen, hundred, thirteen, twenty</p>
# <p class="least_words">read, stone, distancing, digital, whatsapp, ebola, serve, museum, while</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">2.934108018875122</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newcriterion.com/blogs/dispatch/week-in-review-11579">Week in review</a>
# <br></br>
# <br></br>
# <p class="top_words">output, books, iii, crisis, thereby, indeed, etc, chairman</p>
# <p class="least_words">beloved, alongside, archaeologists, finds, explains, writes, says, latest, taylor, aren</p>
# </td>
# <td class="publication">The New Criterion Latest Blog</td>
# <td class="logit">2.92802095413208</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.commonwealmagazine.org/haves-and-have-nots">The Haves and the Have-Nots</a>
# <br></br>
# <br></br>
# <p class="top_words">friends, business, the, sound, mined, assumptions, view, fourteen, seventy</p>
# <p class="least_words">wrote, stars, track, writes, scandal, drops, island, health, featured, seemingly</p>
# </td>
# <td class="publication">Commonweal Magazine</td>
# <td class="logit">2.8799922466278076</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.city-journal.org/kipling-the-irish-guards-in-the-great-war">The Other Great War</a>
# <br></br>
# <br></br>
# <p class="top_words">knew, civilization, archive, corpse, enemy, manner, troubled, naïve, headquarters</p>
# <p class="least_words">wrote, 2020, esque, including, joined, getty, told, also, fire</p>
# </td>
# <td class="publication">City Journal</td>
# <td class="logit">2.8781964778900146</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.smh.com.au/national/the-decline-of-universities-where-students-are-customers-and-academics-itinerant-workers-20200528-p54xbd.html?ref=rss&utm_medium=rss&utm_source=rss_feed">The decline of universities, where students are customers and academics itinerant workers</a>
# <br></br>
# <br></br>
# <p class="top_words">stuff, the, friend, germans, lecture, box, system, economies, revolution, talk</p>
# <p class="least_words">trump, stone, digital, shows, defence, wellbeing, holiday, meanwhile, says, galloway</p>
# </td>
# <td class="publication">Sydney Morning Herald - Latest News</td>
# <td class="logit">2.8624699115753174</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.nytimes.com/2020/05/29/business/stock-market-today-coronavirus.html">Live Stock Market News During the Coronavirus Pandemic</a>
# <br></br>
# <br></br>
# <p class="top_words">almost, ask, whatever, extent, bear, the, secondly, mentioned</p>
# <p class="least_words">essentially, focused, tremendous, women, testing, outbreak, really</p>
# </td>
# <td class="publication">NYT > Top Stories</td>
# <td class="logit">2.803107261657715</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.economist.com/books-and-arts/2020/05/16/even-before-lockdowns-confinement-was-part-of-human-life">Even before lockdowns, confinement was part of human life</a>
# <br></br>
# <br></br>
# <p class="top_words">mood, abba, arms, money, cubicle, paradox, notion, obvious, idle, cell</p>
# <p class="least_words">stone, characters, wrote, metres, while, stars, metre, travelled, pilot, above</p>
# </td>
# <td class="publication">Economist Books and arts</td>
# <td class="logit">2.771440029144287</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/zmeL8gee3h0/">FaceTime, with Lipstick</a>
# <br></br>
# <br></br>
# <p class="top_words">gray, chairman, balance, hair, israel, afternoon, avenue, image, ten, fifteen</p>
# <p class="least_words">photograph, explaining, reminder, boost, video, horror, previously, boosting, disproportionately</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">2.766542673110962</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.wsj.com/articles/why-the-fed-may-not-duck-inflation-this-time-11590707317">Why the Fed May Not Duck Inflation This Time</a>
# <br></br>
# <br></br>
# <p class="top_words">chairman, liquidity, obama, credit, dec, stimulus</p>
# <p class="least_words">lawmakers, due, congress, reimpose, finding, during, also, allows</p>
# </td>
# <td class="publication">WSJ Opinion</td>
# <td class="logit">2.758643388748169</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.city-journal.org/paris-lockdown-street-litter">Clean-up Duty</a>
# <br></br>
# <br></br>
# <p class="top_words">cannot, soft, hardly, empty, cigarette, logic, the, behave, hundred</p>
# <p class="least_words">percent, while, doesn, bravo, gives, during, also</p>
# </td>
# <td class="publication">City Journal</td>
# <td class="logit">2.734053373336792</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/860845135/people-cant-see-it-but-this-grocery-worker-still-wears-lipstick-under-her-mask?utm_medium=RSS&utm_campaign=news">People Can't See It, But This Grocery Worker Still Wears Lipstick Under Her Mask</a>
# <br></br>
# <br></br>
# <p class="top_words">the, meetings, neighbor, image, toggle, enlarge, caption</p>
# <p class="least_words">read, quarantine, violating, says, said, during, ortiz, told</p>
# </td>
# <td class="publication">News : NPR</td>
# <td class="logit">2.689770460128784</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/hold-your-applause/">Hold Your Applause</a>
# <br></br>
# <br></br>
# <p class="top_words">afternoon, download, twelve, hundred, fifty, thirteen, forty, sixty, twentieth</p>
# <p class="least_words">trump, read, wednesday, thursday, monday, tuesday, macron, friday, confirmed</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.590306282043457</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.americanbanker.com/opinion/lender-beware-emergency-relief-efforts-are-inherently-risky">Lender beware: Emergency relief efforts are inherently risky</a>
# <br></br>
# <br></br>
# <p class="top_words">bonuses, summary, bankers, statistical, clients, liquidity, balance, credit</p>
# <p class="least_words">changing, essentially, while, specifically, follows, warned, ahead, diversity, says, aren</p>
# </td>
# <td class="publication">American Banker: Feed</td>
# <td class="logit">2.5690088272094727</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.economist.com/business/2020/05/02/imagine-the-post-pandemic-misery-of-business-travel">Imagine the post-pandemic misery of business travel</a>
# <br></br>
# <br></br>
# <p class="top_words">bottle, buffet, managers, meetings, reader, obvious, clients, cell, afternoon</p>
# <p class="least_words">distancing, metres, 2020, while, doesn, centre, pilot, beverage, safely</p>
# </td>
# <td class="publication">Economist Business</td>
# <td class="logit">2.5317444801330566</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://spectator.org/how-the-u-s-and-india-can-counteract-china-coronavirus-covid-19/">How the U.S. and India Can Counteract China</a>
# <br></br>
# <br></br>
# <p class="top_words">money, view, sideline, jihad, indeed, politburo, behavior, shiite, pages</p>
# <p class="least_words">while, tensions, airbase, downplay, focusing, denying, trade, joint, impetus</p>
# </td>
# <td class="publication">The American Spectator</td>
# <td class="logit">2.4929568767547607</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/from-now-on-i-vow-only-to-read-fiction/">From Now On, I Vow Only to Read Fiction</a>
# <br></br>
# <br></br>
# <p class="top_words">assumed, concentrate, wondered, occupy, blog, ten, thirty, twenty, blogs</p>
# <p class="least_words">trump, read, tweeted, donald, clarity, netflix, quarantine, recap, wrote</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.4878695011138916</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/864721225/friends-remember-george-floyd-as-a-gentle-giant?utm_medium=RSS&utm_campaign=morningedition">Friends Remember George Floyd As A Gentle Giant</a>
# <br></br>
# <br></br>
# <p class="top_words">friend, archived, contractor, smile, anymore, org, inc, pages, copyright</p>
# <p class="least_words">sparked, video, 2020, literally, hasn, finding, week, puerto</p>
# </td>
# <td class="publication">Morning Edition : NPR</td>
# <td class="logit">2.478846549987793</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newcriterion.com/blogs/dispatch/may-days">May days</a>
# <br></br>
# <br></br>
# <p class="top_words">page, indeed, startling, talk, eighty, indispensable, thirty, seventy, twenty</p>
# <p class="least_words">related, 2020, journal, saturday, fdr, ahead, bells, plans</p>
# </td>
# <td class="publication">The New Criterion Latest Blog</td>
# <td class="logit">2.472825527191162</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/the-influence-of-anxiety/">The Influence of Anxiety</a>
# <br></br>
# <br></br>
# <p class="top_words">failure, witted, indeed, talk, conferences, afternoon, nervous, concentrate, advertisement</p>
# <p class="least_words">photograph, read, twitter, highlight, wrote, while, watch, thinks, lets</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.4024887084960938</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/a-walk-in-the-park/">A Walk in the Park</a>
# <br></br>
# <br></br>
# <p class="top_words">rim, drive, afternoon, eighteen, jeans, avenue, ten, twenty, caption</p>
# <p class="least_words">photograph, trump, read, quarantine, stone, distancing, shows, tech, lincoln</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.3417439460754395</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.newyorker.com/science/medical-dispatch/the-risks-of-normalizing-the-coronavirus">When COVID-19 Starts to Feel Normal</a>
# <br></br>
# <br></br>
# <p class="top_words">ten, hundred, eighteenth, forty, thirty, cent, sixty, seventy, twenty</p>
# <p class="least_words">reminder, distancing, isn, while, watch, reported, exclude, particularly</p>
# </td>
# <td class="publication">Everything</td>
# <td class="logit">2.335841178894043</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.project-syndicate.org/commentary/will-covid19-pandemic-change-roles-of-markets-and-state-by-jean-pisani-ferry-2020-05">The Uncertain Pandemic Consensus</a>
# <br></br>
# <br></br>
# <p class="top_words">crisis, view, obvious, globalization, fiscal, whereas, credit, interviews</p>
# <p class="least_words">trump, donald, reminder, bolsonaro, jair, previously, serve, tensions, argued</p>
# </td>
# <td class="publication">Project Syndicate</td>
# <td class="logit">2.3186607360839844</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/i-must-leave-my-house/">I Must Leave My House</a>
# <br></br>
# <br></br>
# <p class="top_words">neighbor, cell, israel, obama, avenue, occupy, mail, web</p>
# <p class="least_words">tuesday, lightly, clarity, spokesperson, quarantine, friday, distancing, digital, video</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.304269313812256</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.theglobalist.com/argentina-default-imf-corruption-covid19/">Argentina: Greed, Bonds, COVID and Your Cash</a>
# <br></br>
# <br></br>
# <p class="top_words">default, money, crisis, greedy, argentine, indeed, greed, behavior, incentives, credit</p>
# <p class="least_words">related, 2018, watch, warned, meanwhile, key, twist, chair, basically</p>
# </td>
# <td class="publication">The Globalist</td>
# <td class="logit">2.2955322265625</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.economist.com/special-report/2020/03/26/africa-is-changing-so-rapidly-it-is-becoming-hard-to-ignore">Africa is changing so rapidly, it is becoming hard to ignore</a>
# <br></br>
# <br></br>
# <p class="top_words">money, crisis, failure, economies, commodity, harvard</p>
# <p class="least_words">2014, according, centre, says, slavery, climate, radicalisation, trade, entering, also</p>
# </td>
# <td class="publication">Economist Special report</td>
# <td class="logit">2.2743492126464844</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.project-syndicate.org/commentary/bleak-preliminary-history-of-2020s-by-yanis-varoufakis-2020-05">A Chronicle of a Lost Decade Foretold</a>
# <br></br>
# <br></br>
# <p class="top_words">twenties, system, economies, equilibrium, talk, bankers, globalization, thatcher, interviews</p>
# <p class="least_words">season, tech, analytica, 2020, ahead, condemned, communities, activists, vulnerable</p>
# </td>
# <td class="publication">Project Syndicate</td>
# <td class="logit">2.240781307220459</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.dissentmagazine.org/blog/hot-bothered-has-the-fracking-bubble-finally-burst-with-bethany-mclean">Hot & Bothered: Has the Fracking Bubble Finally Burst? with Bethany McLean</a>
# <br></br>
# <br></br>
# <p class="top_words">crisis, kill, bubble, patreon, oil, talk, economics, ebook</p>
# <p class="least_words">vox, changing, episode, kate, plumer, fuel, proposal, deal</p>
# </td>
# <td class="publication">Dissent Magazine</td>
# <td class="logit">2.2318055629730225</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/udLHCX1JjBc/">Pandemic Marriage, Ménage, & Me</a>
# <br></br>
# <br></br>
# <p class="top_words">talk, explanations, satisfaction, articles, assumed, neighborhood, balance, hair, occasional, interviews</p>
# <p class="least_words">trump, read, quarantine, chart, added, isn, while, sunday</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">2.149688959121704</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.newyorker.com/culture/video-dept/the-case-for-eating-crickets">The Case for Eating Crickets</a>
# <br></br>
# <br></br>
# <p class="top_words">box, sitting, oil, telephone, thousand, wondered, hundred, thirteen, cent, twenty</p>
# <p class="least_words">2016, quarantine, wireless, added, video, alongside, museum, adding, above, explains</p>
# </td>
# <td class="publication">Everything</td>
# <td class="logit">2.1489310264587402</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.technologyreview.com/2020/05/28/1002326/business-workplace-reopening-safely-testing-covid-19/">The CEO’s guide to safely reopening the workplace</a>
# <br></br>
# <br></br>
# <p class="top_words">behave, economies, indeed, economics, neighborhood, suppose, hair, credit</p>
# <p class="least_words">changing, quarantine, distancing, digital, 2020, previously, presidents, while, sanitizer</p>
# </td>
# <td class="publication">Top News - MIT Technology Review</td>
# <td class="logit">2.144171953201294</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/my-lanyarded-brethren/">My Lanyarded Brethren</a>
# <br></br>
# <br></br>
# <p class="top_words">gray, mentioned, neighborhood, occasional, bureaucrats, translated, forty, thirty</p>
# <p class="least_words">trump, read, twitter, tuesday, 2016, sanders, bernie, wrote, 2010s</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.1248412132263184</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/stop-making-points/">Stop Making Points</a>
# <br></br>
# <br></br>
# <p class="top_words">thousand, tolstoy, drive, afternoon, ten, kilometers, forty, thirty, twenty</p>
# <p class="least_words">pic, explaining, monday, quarantine, wrote, whatsapp, gif, while, doesn</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.111539363861084</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.wsj.com/articles/canadas-banks-take-earnings-hit-from-loan-loss-provisions-11590779182">Canada's Banks Take Earnings Hit from Loss Provisions</a>
# <br></br>
# <br></br>
# <p class="top_words">crisis, bubble, economies, fiscal, inc, credit, stimulus, copyright</p>
# <p class="least_words">2021, 2020, according, earnings, warned, vulnerable, reported, meanwhile, canada, commerce</p>
# </td>
# <td class="publication">WSJ.com: Markets</td>
# <td class="logit">2.104137659072876</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/in-bloom/">In Bloom</a>
# <br></br>
# <br></br>
# <p class="top_words">impersonal, obvious, typed, neighborhood, thousand, neighbor, cell, twelve, hundred</p>
# <p class="least_words">read, quarantine, added, wrote, horror, newest, while, watch, doesn</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">2.09391188621521</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.telegraph.co.uk/global-health/science-and-disease/economic-terms-covid-19-might-ebola-uk-has-chance-rise-challenge/">In economic terms Covid-19 might as well be Ebola â but the UK has a chance to rise to the challenge</a>
# <br></br>
# <br></br>
# <p class="top_words">whom, daniel, lockdown, the, nevertheless, themselves, cluster, sensible, statistical</p>
# <p class="least_words">trump, boris, during, virus, health, fire, date, isolating, than</p>
# </td>
# <td class="publication">Telegraph</td>
# <td class="logit">2.001974105834961</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.foreignaffairs.com/articles/united-states/2020-05-29/pandemic-financial-crisis">The Age of Magic Money</a>
# <br></br>
# <br></br>
# <p class="top_words">bush, moreover, pages, stimulus, ten</p>
# <p class="least_words">2017, 2015, digital, wrote, 2021, percent, 2020, presidents, boosting, affordable</p>
# </td>
# <td class="publication">Foreign Affairs Feed</td>
# <td class="logit">1.9944558143615723</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/vFmUzboYrUk/">Art in Isolation: The Delicate Paintings of Edo Japan</a>
# <br></br>
# <br></br>
# <p class="top_words">urbanization, ninety, harvard, economics, seventeenth, hundred, eighteenth, nineteenth, twenty</p>
# <p class="least_words">curator, related, boost, 2020, alongside, museum, revealed, due, popular, neil</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">1.9771158695220947</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.economist.com/business/2020/03/21/how-corporate-leaders-should-act-in-a-crisis">How corporate leaders should act in a crisis</a>
# <br></br>
# <br></br>
# <p class="top_words">supply, crisis, failure, invisible, meetings, obvious, clients, suck</p>
# <p class="least_words">rolling, chart, organisation, pretty, defence, adding, says, latest, deal</p>
# </td>
# <td class="publication">Economist Business</td>
# <td class="logit">1.9665528535842896</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://foreignpolicy.com/2020/05/29/stock-market-rally-coronavirus-pandemic/">Why Are Stocks Soaring in the Middle of a Pandemic?</a>
# <br></br>
# <br></br>
# <p class="top_words">fiscal, liquidity, balance, drive, credit</p>
# <p class="least_words">distancing, takeaway, percent, while, backstop, doesn, argued, 2013, above</p>
# </td>
# <td class="publication">Foreign Policy</td>
# <td class="logit">1.965714454650879</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.smh.com.au/sport/shifting-the-goalposts-our-new-sporting-life-20200529-p54xng.html?ref=rss&utm_medium=rss&utm_source=rss_feed">Shifting the goalposts: our new sporting life</a>
# <br></br>
# <br></br>
# <p class="top_words">bubble, henceforth, headquarters, chairman, assumed, liquidity, moreover, credit, cent</p>
# <p class="least_words">changing, highlight, shows, 2020, isn, serve, while, pop, thinks</p>
# </td>
# <td class="publication">Sydney Morning Herald - Latest News</td>
# <td class="logit">1.965591549873352</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/extinction-event/">Extinction Event</a>
# <br></br>
# <br></br>
# <p class="top_words">ten, fifteen, hundred, fifty, forty, thirty, sixty, seventy, twenty</p>
# <p class="least_words">trump, read, 2017, 2016, distancing, percent, 2020, alongside, presidents</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">1.949511170387268</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://thenewinquiry.com/chaos-orders-us-a-letter-from-paris/">Chaos Orders Us: A Letter From Paris</a>
# <br></br>
# <br></br>
# <p class="top_words">etc, equilibrium, remembers, thousand, hollande, evidently, image, fifty, twenty</p>
# <p class="least_words">thursday, monday, related, quarantine, macron, 2015, wrote, emmanuel, percent</p>
# </td>
# <td class="publication">The New Inquiry</td>
# <td class="logit">1.9465746879577637</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/7_DhlYEzD7c/">In the Vanguard of Trio Jazz with Micah Thomas</a>
# <br></br>
# <br></br>
# <p class="top_words">mentioned, balance, loft, drive, avenue, fifteen, thirty, sixty, twenty</p>
# <p class="least_words">tuesday, 2016, jamal, added, wrote, horror, lincoln, isn, 2018</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">1.9141948223114014</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://quillette.com/2020/05/24/do-we-really-want-a-new-cold-war/">Do We Really Want a New Cold War?</a>
# <br></br>
# <br></br>
# <p class="top_words">supply, rational, crisis, system, mutual, belknap, comparative, harvard, libertarians, bureaucrats</p>
# <p class="least_words">trump, pretty, whatsapp, snap, isn, while, viral, tensions, doesn</p>
# </td>
# <td class="publication">Quillette</td>
# <td class="logit">1.9086610078811646</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://nplusonemag.com/online-only/online-only/aden-dispatch/">Aden Dispatch</a>
# <br></br>
# <br></br>
# <p class="top_words">sitting, system, arab, obvious, attractive, neighborhood, hair, drive</p>
# <p class="least_words">2015, video, while, dedicated, thinks, hodeidah, clip, shooting, above</p>
# </td>
# <td class="publication">n+1</td>
# <td class="logit">1.8805232048034668</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.foreignaffairs.com/articles/united-states/2020-05-28/spanish-flu-didnt-wreck-global-economy">The Spanish Flu Didn’t Wreck the Global Economy</a>
# <br></br>
# <br></br>
# <p class="top_words">tags, behave, economies, dozen, thirties, faculty, campus, stimulus, hundred</p>
# <p class="least_words">quarantine, distancing, beloved, percent, according, vulnerable, reported, meanwhile, refugees</p>
# </td>
# <td class="publication">Foreign Affairs Feed</td>
# <td class="logit">1.8761999607086182</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://newcriterion.com/blogs/dispatch/honoring-victimhood">Honoring victimhood</a>
# <br></br>
# <br></br>
# <p class="top_words">headlines, assumed, indispensable, afternoon, pages, homosexuals</p>
# <p class="least_words">trump, read, monday, ardern, wrote, jacinda, percent, while, adding</p>
# </td>
# <td class="publication">The New Criterion Latest Blog</td>
# <td class="logit">1.852874994277954</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/864699431/alabama-man-serves-homeless-community-by-offering-laundry-service?utm_medium=RSS&utm_campaign=morningedition">Alabama Man Serves Homeless Community By Offering Laundry Service</a>
# <br></br>
# <br></br>
# <p class="top_words">parking, shirt, org, inc, avenue, pages, copyright</p>
# <p class="least_words">distancing, video, 2020, serve, verse, while, moments, sanitizer, ahead</p>
# </td>
# <td class="publication">Morning Edition : NPR</td>
# <td class="logit">1.8097984790802002</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.project-syndicate.org/commentary/limits-covid19-monetary-policy-by-paola-subacchi-2020-05">The Limits of Extreme COVID Monetary Policy</a>
# <br></br>
# <br></br>
# <p class="top_words">liquidity, balance, drive, whereas, euro, credit, stimulus, interviews</p>
# <p class="least_words">reportedly, serve, while, doesn, track, ahead, meanwhile, powell</p>
# </td>
# <td class="publication">Project Syndicate</td>
# <td class="logit">1.7895433902740479</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.economist.com/special-report/2020/04/08/south-koreas-transformation-is-still-fragile">South Koreaâs transformation is still fragile</a>
# <br></br>
# <br></br>
# <p class="top_words">sensible, begun, obvious, talk, satisfaction, harvard, fiscal, stimulus</p>
# <p class="least_words">changing, 2010s, disproportionately, highlighted, says, particularly, said, during, also</p>
# </td>
# <td class="publication">Economist Special report</td>
# <td class="logit">1.765859603881836</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://techcrunch.com/2020/05/29/how-startups-can-leverage-elastic-services-for-cost-optimization/">How startups can leverage elastic services for cost optimization</a>
# <br></br>
# <br></br>
# <p class="top_words">organizations, optimization, business, the, strategic, crisis, operational, obvious</p>
# <p class="least_words">tech, according, startup, due, retail, startups, providing, has, mature</p>
# </td>
# <td class="publication">TechCrunch</td>
# <td class="logit">1.7581679821014404</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.npr.org/2020/05/29/864699410/s-c-hospital-system-tells-non-covid-19-patients-its-safe-to-return?utm_medium=RSS&utm_campaign=morningedition">S.C. Hospital System Tells Non-COVID-19 Patients It's Safe To Return</a>
# <br></br>
# <br></br>
# <p class="top_words">money, contractor, system, dozen, economics, org, inc, pages, copyright</p>
# <p class="least_words">2020, bunch, above, says, aren, week, vaccinations</p>
# </td>
# <td class="publication">Morning Edition : NPR</td>
# <td class="logit">1.741795539855957</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/nybooks/~3/MwREaW-ud98/">From Brexit to Covid: A Very British Debacle</a>
# <br></br>
# <br></br>
# <p class="top_words">talk, ninety, preposterous, hair, occasional, image, twelve, nineteenth</p>
# <p class="least_words">brexit, 2016, season, shows, boris, percent, denies, while</p>
# </td>
# <td class="publication">The New York Review of Books</td>
# <td class="logit">1.7195746898651123</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="http://feedproxy.google.com/~r/theamericanscholar/yaSQ/~3/xMJrIcv3LeM/">Our Posthumous Lives</a>
# <br></br>
# <br></br>
# <p class="top_words">productive, the, occasions, sitting, notion, dozen, etc, reader</p>
# <p class="least_words">wrote, percent, while, celebrate, moments, vulnerable, segment, favorite, particularly, said</p>
# </td>
# <td class="publication">The American Scholar</td>
# <td class="logit">1.6768460273742676</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.coindesk.com/serious-decentralization-we-need-to-measure-it">To Get Serious About Decentralization, We Need to Measure It</a>
# <br></br>
# <br></br>
# <p class="top_words">distribution, business, the, introduction, economies, protocol, harvard, economics, liquidity</p>
# <p class="least_words">added, tech, code, while, argued, outcry, popular, reported, stalwart, originally</p>
# </td>
# <td class="publication">CoinDesk</td>
# <td class="logit">1.6756579875946045</td>
# </tr>
# <tr>
# <td class="title mdl-data-table__cell--non-numeric"><a class="article_link" href="https://www.project-syndicate.org/commentary/changes-in-financial-regulation-since-pandemic-by-howard-davies-2020-05">Regulating in a Pandemic</a>
# <br></br>
# <br></br>
# <p class="top_words">mainly, view, explanations, bankers, economics, liquidity, credit, ten, interviews</p>
# <p class="least_words">confirmed, while, buybacks, argued, ahead, dip, typically</p>
# </td>
# <td class="publication">Project Syndicate</td>
# <td class="logit">1.6397805213928223</td>
# </tr>
